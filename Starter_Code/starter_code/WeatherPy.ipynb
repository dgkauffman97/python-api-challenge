# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric" 
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url)
        city_json = city_weather.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_json["coord"]["lat"]
        city_lon = city_json["coord"]["lon"]
        city_max_temp = city_json["main"]["temp_max"]
        city_humidity = city_json["main"]["humidity"]
        city_clouds = city_json["clouds"]["all"]
        city_wind = city_json["wind"]["speed"]
        city_country = city_json["sys"]["country"]
        city_date = city_json["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lon, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | blackmans bay
# Processing Record 2 of Set 1 | shush
# Processing Record 3 of Set 1 | dunkwa
# Processing Record 4 of Set 1 | chernomorskoye
# Processing Record 5 of Set 1 | viedma
# Processing Record 6 of Set 1 | aoulef
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | charters towers
# Processing Record 10 of Set 1 | vilyuysk
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | opuwo
# Processing Record 14 of Set 1 | polyarnyy
# Processing Record 15 of Set 1 | lompoc
# Processing Record 16 of Set 1 | shimokizukuri
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | cabo san lucas
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | claremont
# Processing Record 23 of Set 1 | edinburgh of the seven seas
# Processing Record 24 of Set 1 | port-aux-francais
# Processing Record 25 of Set 1 | wailua homesteads
# Processing Record 26 of Set 1 | kharp
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | baoqing
# Processing Record 29 of Set 1 | melekeok village
# Processing Record 30 of Set 1 | oranjemund
# Processing Record 31 of Set 1 | juquitiba
# Processing Record 32 of Set 1 | west island
# Processing Record 33 of Set 1 | adamstown
# Processing Record 34 of Set 1 | lazaro cardenas
# Processing Record 35 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 36 of Set 1 | capayan
# Processing Record 37 of Set 1 | puerto natales
# Processing Record 38 of Set 1 | tiksi
# Processing Record 39 of Set 1 | qaqortoq
# Processing Record 40 of Set 1 | waitangi
# Processing Record 41 of Set 1 | iskateley
# Processing Record 42 of Set 1 | invercargill
# Processing Record 43 of Set 1 | gadzhiyevo
# Processing Record 44 of Set 1 | ba
# City not found. Skipping...
# Processing Record 45 of Set 1 | cannonvale
# Processing Record 46 of Set 1 | aberdeen
# Processing Record 47 of Set 1 | sola
# Processing Record 48 of Set 1 | lorengau
# Processing Record 49 of Set 1 | businga
# Processing Record 50 of Set 1 | thompson
# Processing Record 0 of Set 2 | pirajui
# Processing Record 1 of Set 2 | grytviken
# Processing Record 2 of Set 2 | naze
# Processing Record 3 of Set 2 | wattegama
# Processing Record 4 of Set 2 | luganville
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | port blair
# Processing Record 7 of Set 2 | enewetak
# Processing Record 8 of Set 2 | ta`u
# Processing Record 9 of Set 2 | langsa
# Processing Record 10 of Set 2 | colonia
# Processing Record 11 of Set 2 | nemuro
# Processing Record 12 of Set 2 | bilibino
# Processing Record 13 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 14 of Set 2 | st. john's
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | kirakira
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | margaret river
# Processing Record 19 of Set 2 | hawaiian paradise park
# Processing Record 20 of Set 2 | kidal
# Processing Record 21 of Set 2 | talnakh
# Processing Record 22 of Set 2 | katima mulilo
# Processing Record 23 of Set 2 | karatau
# Processing Record 24 of Set 2 | kone
# Processing Record 25 of Set 2 | malyn
# Processing Record 26 of Set 2 | al ghayzah
# Processing Record 27 of Set 2 | sangkhla buri
# Processing Record 28 of Set 2 | paciran
# Processing Record 29 of Set 2 | papatowai
# Processing Record 30 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | ambam
# Processing Record 33 of Set 2 | eyl
# Processing Record 34 of Set 2 | richards bay
# Processing Record 35 of Set 2 | tlahualilo de zaragoza
# Processing Record 36 of Set 2 | lere
# Processing Record 37 of Set 2 | ouadda
# Processing Record 38 of Set 2 | conde
# Processing Record 39 of Set 2 | atafu village
# Processing Record 40 of Set 2 | kimbe
# Processing Record 41 of Set 2 | ancud
# Processing Record 42 of Set 2 | santa terezinha
# Processing Record 43 of Set 2 | vorgashor
# Processing Record 44 of Set 2 | holualoa
# Processing Record 45 of Set 2 | kananga
# Processing Record 46 of Set 2 | punta arenas
# Processing Record 47 of Set 2 | aral
# Processing Record 48 of Set 2 | west bay
# Processing Record 49 of Set 2 | iqaluit
# Processing Record 0 of Set 3 | puerto carreno
# Processing Record 1 of Set 3 | port lincoln
# Processing Record 2 of Set 3 | tazovsky
# Processing Record 3 of Set 3 | al kharijah
# Processing Record 4 of Set 3 | afaahiti
# Processing Record 5 of Set 3 | tangalle
# Processing Record 6 of Set 3 | stanley
# Processing Record 7 of Set 3 | funafuti
# Processing Record 8 of Set 3 | port mathurin
# Processing Record 9 of Set 3 | severo-yeniseyskiy
# Processing Record 10 of Set 3 | corinto
# Processing Record 11 of Set 3 | igarape acu
# Processing Record 12 of Set 3 | daru
# Processing Record 13 of Set 3 | ust-nera
# Processing Record 14 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 3 | coyhaique
# Processing Record 16 of Set 3 | al qubbah
# Processing Record 17 of Set 3 | kupang
# Processing Record 18 of Set 3 | pangody
# Processing Record 19 of Set 3 | ungsang-nodongjagu
# Processing Record 20 of Set 3 | medford
# Processing Record 21 of Set 3 | puerto quijarro
# Processing Record 22 of Set 3 | porto novo
# Processing Record 23 of Set 3 | san-pedro
# Processing Record 24 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 25 of Set 3 | sisimiut
# Processing Record 26 of Set 3 | palmer
# Processing Record 27 of Set 3 | anadyr
# Processing Record 28 of Set 3 | maceio
# Processing Record 29 of Set 3 | kili
# Processing Record 30 of Set 3 | curuca
# Processing Record 31 of Set 3 | urengoy
# Processing Record 32 of Set 3 | oum hadjer
# Processing Record 33 of Set 3 | college
# Processing Record 34 of Set 3 | celica
# Processing Record 35 of Set 3 | alfredton
# Processing Record 36 of Set 3 | tazacorte
# Processing Record 37 of Set 3 | beira
# Processing Record 38 of Set 3 | port douglas
# Processing Record 39 of Set 3 | vilyuchinsk
# Processing Record 40 of Set 3 | la sarre
# Processing Record 41 of Set 3 | nizhneangarsk
# Processing Record 42 of Set 3 | san antonio de pale
# Processing Record 43 of Set 3 | sitka
# Processing Record 44 of Set 3 | haiku-pauwela
# Processing Record 45 of Set 3 | caleta de carquin
# Processing Record 46 of Set 3 | isafjordur
# Processing Record 47 of Set 3 | hamilton
# Processing Record 48 of Set 3 | puerto ayora
# Processing Record 49 of Set 3 | alice springs
# Processing Record 0 of Set 4 | kerikeri
# Processing Record 1 of Set 4 | greenwood
# Processing Record 2 of Set 4 | russkaya polyana
# Processing Record 3 of Set 4 | pacocha
# Processing Record 4 of Set 4 | san andres
# Processing Record 5 of Set 4 | minas de marcona
# Processing Record 6 of Set 4 | choibalsan
# Processing Record 7 of Set 4 | olonkinbyen
# Processing Record 8 of Set 4 | quesnel
# Processing Record 9 of Set 4 | fale old settlement
# Processing Record 10 of Set 4 | gallup
# Processing Record 11 of Set 4 | mount gambier
# Processing Record 12 of Set 4 | remire-montjoly
# Processing Record 13 of Set 4 | turinsk
# Processing Record 14 of Set 4 | cable beach
# City not found. Skipping...
# Processing Record 15 of Set 4 | kiunga
# Processing Record 16 of Set 4 | nishinoomote
# Processing Record 17 of Set 4 | benghazi
# Processing Record 18 of Set 4 | wingham
# Processing Record 19 of Set 4 | ribeira grande
# Processing Record 20 of Set 4 | labrador city
# Processing Record 21 of Set 4 | lubuklinggau
# Processing Record 22 of Set 4 | harstad
# Processing Record 23 of Set 4 | itoman
# Processing Record 24 of Set 4 | ad dawadimi
# Processing Record 25 of Set 4 | crane
# Processing Record 26 of Set 4 | tsiombe
# Processing Record 27 of Set 4 | malvan
# Processing Record 28 of Set 4 | ibirite
# Processing Record 29 of Set 4 | pasni
# Processing Record 30 of Set 4 | bedarieux
# Processing Record 31 of Set 4 | port alfred
# Processing Record 32 of Set 4 | markala
# Processing Record 33 of Set 4 | egilsstadir
# Processing Record 34 of Set 4 | utrik
# Processing Record 35 of Set 4 | palu
# Processing Record 36 of Set 4 | mukalla
# Processing Record 37 of Set 4 | puerto san jose
# Processing Record 38 of Set 4 | gumdag
# Processing Record 39 of Set 4 | barentu
# Processing Record 40 of Set 4 | mirnyy
# Processing Record 41 of Set 4 | hovd
# Processing Record 42 of Set 4 | shiqian
# Processing Record 43 of Set 4 | mata-utu
# Processing Record 44 of Set 4 | saint-francois
# Processing Record 45 of Set 4 | flying fish cove
# Processing Record 46 of Set 4 | steamboat springs
# Processing Record 47 of Set 4 | chifeng
# Processing Record 48 of Set 4 | solnechnyy
# Processing Record 49 of Set 4 | merizo village
# Processing Record 0 of Set 5 | lihue
# Processing Record 1 of Set 5 | kodiak
# Processing Record 2 of Set 5 | arkhangel'sk
# Processing Record 3 of Set 5 | natal
# Processing Record 4 of Set 5 | firuzabad
# Processing Record 5 of Set 5 | hotan
# Processing Record 6 of Set 5 | zhob
# Processing Record 7 of Set 5 | whitehorse
# Processing Record 8 of Set 5 | fada
# Processing Record 9 of Set 5 | myingyan
# Processing Record 10 of Set 5 | hadibu
# Processing Record 11 of Set 5 | puerto baquerizo moreno
# Processing Record 12 of Set 5 | miles city
# Processing Record 13 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 14 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 15 of Set 5 | bonthe
# Processing Record 16 of Set 5 | rabigh
# Processing Record 17 of Set 5 | aromashevo
# Processing Record 18 of Set 5 | launceston
# Processing Record 19 of Set 5 | newton aycliffe
# Processing Record 20 of Set 5 | kanniyakumari
# Processing Record 21 of Set 5 | fort frances
# Processing Record 22 of Set 5 | irtyshsk
# Processing Record 23 of Set 5 | claveria
# Processing Record 24 of Set 5 | saint-philippe
# Processing Record 25 of Set 5 | tomatlan
# Processing Record 26 of Set 5 | kozan
# Processing Record 27 of Set 5 | touros
# Processing Record 28 of Set 5 | saipan
# Processing Record 29 of Set 5 | clarksville
# Processing Record 30 of Set 5 | nova sintra
# Processing Record 31 of Set 5 | ain beni mathar
# City not found. Skipping...
# Processing Record 32 of Set 5 | brokopondo
# Processing Record 33 of Set 5 | bardai
# Processing Record 34 of Set 5 | hilo
# Processing Record 35 of Set 5 | nadym
# Processing Record 36 of Set 5 | selfoss
# Processing Record 37 of Set 5 | ulsteinvik
# Processing Record 38 of Set 5 | dolores
# Processing Record 39 of Set 5 | fort bragg
# Processing Record 40 of Set 5 | akureyri
# Processing Record 41 of Set 5 | nkurenkuru
# City not found. Skipping...
# Processing Record 42 of Set 5 | midvagur
# Processing Record 43 of Set 5 | northam
# Processing Record 44 of Set 5 | iquitos
# Processing Record 45 of Set 5 | coquimbo
# Processing Record 46 of Set 5 | karbala
# Processing Record 47 of Set 5 | orkney
# Processing Record 48 of Set 5 | huangpi
# Processing Record 49 of Set 5 | avarua
# Processing Record 0 of Set 6 | princeton
# Processing Record 1 of Set 6 | ilulissat
# Processing Record 2 of Set 6 | nar'yan-mar
# Processing Record 3 of Set 6 | badger
# Processing Record 4 of Set 6 | lata
# Processing Record 5 of Set 6 | udachny
# Processing Record 6 of Set 6 | machico
# Processing Record 7 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 8 of Set 6 | jinka
# Processing Record 9 of Set 6 | cueramaro
# Processing Record 10 of Set 6 | nabire
# Processing Record 11 of Set 6 | barcelos
# Processing Record 12 of Set 6 | port saint john's
# Processing Record 13 of Set 6 | melilla
# Processing Record 14 of Set 6 | al jawf
# Processing Record 15 of Set 6 | ijuw
# City not found. Skipping...
# Processing Record 16 of Set 6 | tonghae
# Processing Record 17 of Set 6 | port macquarie
# Processing Record 18 of Set 6 | port pirie
# Processing Record 19 of Set 6 | ulladulla
# Processing Record 20 of Set 6 | i-n-salah
# Processing Record 21 of Set 6 | san francisco del rincon
# Processing Record 22 of Set 6 | luderitz
# Processing Record 23 of Set 6 | happy valley-goose bay
# Processing Record 24 of Set 6 | pokhara
# Processing Record 25 of Set 6 | krasnovishersk
# Processing Record 26 of Set 6 | kingston
# Processing Record 27 of Set 6 | tulsipur
# Processing Record 28 of Set 6 | san luis de la loma
# Processing Record 29 of Set 6 | yugorsk
# Processing Record 30 of Set 6 | monterey
# Processing Record 31 of Set 6 | sastobe
# Processing Record 32 of Set 6 | yacuiba
# Processing Record 33 of Set 6 | mahibadhoo
# Processing Record 34 of Set 6 | kapuskasing
# Processing Record 35 of Set 6 | argo
# Processing Record 36 of Set 6 | gorno-altaysk
# Processing Record 37 of Set 6 | imbituba
# Processing Record 38 of Set 6 | zaozersk
# Processing Record 39 of Set 6 | kostanay
# Processing Record 40 of Set 6 | abaza
# Processing Record 41 of Set 6 | sinabang
# Processing Record 42 of Set 6 | lebu
# Processing Record 43 of Set 6 | tessaoua
# Processing Record 44 of Set 6 | cooper's town
# Processing Record 45 of Set 6 | undurkhaan
# Processing Record 46 of Set 6 | klaksvik
# Processing Record 47 of Set 6 | chibougamau
# Processing Record 48 of Set 6 | petrolina
# Processing Record 49 of Set 6 | yuzhno-kurilsk
# Processing Record 0 of Set 7 | cruzeiro do sul
# Processing Record 1 of Set 7 | segou
# Processing Record 2 of Set 7 | salinopolis
# Processing Record 3 of Set 7 | verkhnevilyuysk
# Processing Record 4 of Set 7 | rabo de peixe
# Processing Record 5 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 6 of Set 7 | zapala
# Processing Record 7 of Set 7 | jianguang
# Processing Record 8 of Set 7 | palikir - national government center
# Processing Record 9 of Set 7 | phalodi
# Processing Record 10 of Set 7 | mumbwa
# Processing Record 11 of Set 7 | zakynthos
# Processing Record 12 of Set 7 | jiangyou
# Processing Record 13 of Set 7 | svyetlahorsk
# Processing Record 14 of Set 7 | princeville
# Processing Record 15 of Set 7 | tubarjal
# Processing Record 16 of Set 7 | saint-pierre
# Processing Record 17 of Set 7 | cockburn town
# Processing Record 18 of Set 7 | papao
# Processing Record 19 of Set 7 | mogok
# Processing Record 20 of Set 7 | pangkalanbuun
# Processing Record 21 of Set 7 | barakani
# Processing Record 22 of Set 7 | tadine
# Processing Record 23 of Set 7 | aykhal
# Processing Record 24 of Set 7 | belmonte
# Processing Record 25 of Set 7 | berdigestyakh
# Processing Record 26 of Set 7 | camocim
# Processing Record 27 of Set 7 | san patricio
# Processing Record 28 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 29 of Set 7 | susuman
# Processing Record 30 of Set 7 | xiaoweizhai
# Processing Record 31 of Set 7 | san pablo
# Processing Record 32 of Set 7 | kumagunnam
# Processing Record 33 of Set 7 | merritt island
# Processing Record 34 of Set 7 | rio grande
# Processing Record 35 of Set 7 | nova vicosa
# Processing Record 36 of Set 7 | constantia
# Processing Record 37 of Set 7 | camarinas
# Processing Record 38 of Set 7 | piti village
# Processing Record 39 of Set 7 | shiggaon
# Processing Record 40 of Set 7 | tafuna
# Processing Record 41 of Set 7 | general jose de san martin
# Processing Record 42 of Set 7 | new norfolk
# Processing Record 43 of Set 7 | sidi khaled
# Processing Record 44 of Set 7 | karratha
# Processing Record 45 of Set 7 | laojunmiao
# Processing Record 46 of Set 7 | pisco
# Processing Record 47 of Set 7 | ribadeo
# Processing Record 48 of Set 7 | acajutla
# Processing Record 49 of Set 7 | ampanihy
# Processing Record 0 of Set 8 | akrehamn
# Processing Record 1 of Set 8 | sinop
# Processing Record 2 of Set 8 | alghero
# Processing Record 3 of Set 8 | salinas
# Processing Record 4 of Set 8 | quellon
# Processing Record 5 of Set 8 | renk
# City not found. Skipping...
# Processing Record 6 of Set 8 | kerouane
# Processing Record 7 of Set 8 | kyzyl-suu
# Processing Record 8 of Set 8 | sao gabriel da cachoeira
# Processing Record 9 of Set 8 | center
# Processing Record 10 of Set 8 | afif
# Processing Record 11 of Set 8 | mont-dore
# Processing Record 12 of Set 8 | gaspe
# Processing Record 13 of Set 8 | kavaratti
# Processing Record 14 of Set 8 | hasaki
# Processing Record 15 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 8 | kangding
# Processing Record 17 of Set 8 | hobyo
# Processing Record 18 of Set 8 | mocajuba
# Processing Record 19 of Set 8 | la passe
# Processing Record 20 of Set 8 | wainwright
# Processing Record 21 of Set 8 | fortaleza
# Processing Record 22 of Set 8 | irymple
# Processing Record 23 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 24 of Set 8 | palapag
# Processing Record 25 of Set 8 | thunder bay
# Processing Record 26 of Set 8 | sulejow
# Processing Record 27 of Set 8 | show low
# Processing Record 28 of Set 8 | granada
# Processing Record 29 of Set 8 | west end
# Processing Record 30 of Set 8 | kuqa
# Processing Record 31 of Set 8 | ola
# Processing Record 32 of Set 8 | prince albert
# Processing Record 33 of Set 8 | palo santo
# Processing Record 34 of Set 8 | arteche
# Processing Record 35 of Set 8 | am djarass
# City not found. Skipping...
# Processing Record 36 of Set 8 | ghat
# Processing Record 37 of Set 8 | heihe
# Processing Record 38 of Set 8 | aasiaat
# Processing Record 39 of Set 8 | weno
# Processing Record 40 of Set 8 | ambovombe
# Processing Record 41 of Set 8 | vennesla
# Processing Record 42 of Set 8 | anna regina
# Processing Record 43 of Set 8 | crawfordsville
# Processing Record 44 of Set 8 | sake
# Processing Record 45 of Set 8 | la foa
# Processing Record 46 of Set 8 | ribeira brava
# Processing Record 47 of Set 8 | dunedin
# Processing Record 48 of Set 8 | inhambane
# Processing Record 49 of Set 8 | north bend
# Processing Record 0 of Set 9 | island harbour
# Processing Record 1 of Set 9 | howard springs
# Processing Record 2 of Set 9 | qamdo
# Processing Record 3 of Set 9 | newala kisimani
# Processing Record 4 of Set 9 | padang
# Processing Record 5 of Set 9 | mount pearl
# Processing Record 6 of Set 9 | konongo
# Processing Record 7 of Set 9 | nelson
# Processing Record 8 of Set 9 | olyokminsk
# Processing Record 9 of Set 9 | auki
# Processing Record 10 of Set 9 | ukmerge
# Processing Record 11 of Set 9 | beibei
# Processing Record 12 of Set 9 | ordos
# City not found. Skipping...
# Processing Record 13 of Set 9 | namibe
# Processing Record 14 of Set 9 | tan-tan
# Processing Record 15 of Set 9 | carnarvon
# Processing Record 16 of Set 9 | ugoofaaru
# Processing Record 17 of Set 9 | sept-iles
# Processing Record 18 of Set 9 | cova figueira
# Processing Record 19 of Set 9 | sejny
# Processing Record 20 of Set 9 | el matama
# Processing Record 21 of Set 9 | cidreira
# Processing Record 22 of Set 9 | bamboo flat
# Processing Record 23 of Set 9 | tofol
# Processing Record 24 of Set 9 | antsiranana
# Processing Record 25 of Set 9 | lewistown
# Processing Record 26 of Set 9 | pont-l'abbe
# City not found. Skipping...
# Processing Record 27 of Set 9 | ostersund
# Processing Record 28 of Set 9 | muravlenko
# Processing Record 29 of Set 9 | villa huidobro
# Processing Record 30 of Set 9 | wanlaweyn
# Processing Record 31 of Set 9 | rimouski
# Processing Record 32 of Set 9 | warman
# Processing Record 33 of Set 9 | fougamou
# Processing Record 34 of Set 9 | takamaka
# City not found. Skipping...
# Processing Record 35 of Set 9 | portland
# Processing Record 36 of Set 9 | suez
# Processing Record 37 of Set 9 | virginia beach
# Processing Record 38 of Set 9 | yaren
# Processing Record 39 of Set 9 | sergeyevka
# Processing Record 40 of Set 9 | san juan pueblo
# Processing Record 41 of Set 9 | fisterra
# Processing Record 42 of Set 9 | kizner
# Processing Record 43 of Set 9 | bodo
# Processing Record 44 of Set 9 | grand island
# Processing Record 45 of Set 9 | ketchikan
# Processing Record 46 of Set 9 | manta
# Processing Record 47 of Set 9 | enid
# Processing Record 48 of Set 9 | sorong
# Processing Record 49 of Set 9 | banda aceh
# Processing Record 0 of Set 10 | kavieng
# Processing Record 1 of Set 10 | usinsk
# Processing Record 2 of Set 10 | kokopo
# Processing Record 3 of Set 10 | mandan
# Processing Record 4 of Set 10 | vorkuta
# Processing Record 5 of Set 10 | twon-brass
# Processing Record 6 of Set 10 | sokoni
# Processing Record 7 of Set 10 | chaoyang
# Processing Record 8 of Set 10 | tamanrasset
# Processing Record 9 of Set 10 | nagqu
# Processing Record 10 of Set 10 | mejit
# Processing Record 11 of Set 10 | quibala
# Processing Record 12 of Set 10 | luena
# Processing Record 13 of Set 10 | greymouth
# Processing Record 14 of Set 10 | marolambo
# Processing Record 15 of Set 10 | abepura
# Processing Record 16 of Set 10 | nuku'alofa
# Processing Record 17 of Set 10 | uturoa
# Processing Record 18 of Set 10 | asau village
# City not found. Skipping...
# Processing Record 19 of Set 10 | burang
# Processing Record 20 of Set 10 | yeppoon
# Processing Record 21 of Set 10 | siguatepeque
# Processing Record 22 of Set 10 | chaman
# Processing Record 23 of Set 10 | ponta delgada
# Processing Record 24 of Set 10 | matoury
# Processing Record 25 of Set 10 | kyabe
# Processing Record 26 of Set 10 | coracora
# Processing Record 27 of Set 10 | buka
# Processing Record 28 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 29 of Set 10 | presidente epitacio
# Processing Record 30 of Set 10 | orsk
# Processing Record 31 of Set 10 | tura
# Processing Record 32 of Set 10 | peterhead
# Processing Record 33 of Set 10 | abaete
# Processing Record 34 of Set 10 | aripuana
# Processing Record 35 of Set 10 | vila velha
# Processing Record 36 of Set 10 | nelson bay
# Processing Record 37 of Set 10 | suphan buri
# Processing Record 38 of Set 10 | mana
# Processing Record 39 of Set 10 | yangor
# City not found. Skipping...
# Processing Record 40 of Set 10 | sechura
# Processing Record 41 of Set 10 | praia da vitoria
# Processing Record 42 of Set 10 | rattvik
# City not found. Skipping...
# Processing Record 43 of Set 10 | erdemli
# Processing Record 44 of Set 10 | general acha
# Processing Record 45 of Set 10 | conception bay south
# Processing Record 46 of Set 10 | zinjibar
# Processing Record 47 of Set 10 | rongelap
# Processing Record 48 of Set 10 | ebaye
# Processing Record 49 of Set 10 | keflavik
# Processing Record 0 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 1 of Set 11 | howrah
# Processing Record 2 of Set 11 | villa dolores
# Processing Record 3 of Set 11 | catemaco
# Processing Record 4 of Set 11 | mili
# Processing Record 5 of Set 11 | diebougou
# Processing Record 6 of Set 11 | sidi akkacha
# Processing Record 7 of Set 11 | novodvinsk
# Processing Record 8 of Set 11 | gulnar
# Processing Record 9 of Set 11 | blytheville
# Processing Record 10 of Set 11 | jobabo
# Processing Record 11 of Set 11 | plettenberg bay
# Processing Record 12 of Set 11 | codrington
# Processing Record 13 of Set 11 | buala
# Processing Record 14 of Set 11 | vernon
# Processing Record 15 of Set 11 | shetpe
# Processing Record 16 of Set 11 | tutong
# Processing Record 17 of Set 11 | kalmunai
# Processing Record 18 of Set 11 | venelles
# Processing Record 19 of Set 11 | great falls
# Processing Record 20 of Set 11 | cururupu
# Processing Record 21 of Set 11 | naryn
# Processing Record 22 of Set 11 | shingu
# Processing Record 23 of Set 11 | geraldton
# Processing Record 24 of Set 11 | igarka
# Processing Record 25 of Set 11 | tolanaro
# Processing Record 26 of Set 11 | grove city
# Processing Record 27 of Set 11 | fortuna
# Processing Record 28 of Set 11 | patnagarh
# Processing Record 29 of Set 11 | ulanhot
# Processing Record 30 of Set 11 | nuuk
# Processing Record 31 of Set 11 | cambria
# Processing Record 32 of Set 11 | ad dabbah
# Processing Record 33 of Set 11 | el trebol
# Processing Record 34 of Set 11 | fort saskatchewan
# Processing Record 35 of Set 11 | katabu
# Processing Record 36 of Set 11 | dalai
# Processing Record 37 of Set 11 | harlingen
# Processing Record 38 of Set 11 | masterton
# Processing Record 39 of Set 11 | inekar
# City not found. Skipping...
# Processing Record 40 of Set 11 | kruisfontein
# Processing Record 41 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 42 of Set 11 | arno
# Processing Record 43 of Set 11 | pazaryolu
# Processing Record 44 of Set 11 | broome
# Processing Record 45 of Set 11 | as sulayyil
# Processing Record 46 of Set 11 | ajuy
# Processing Record 47 of Set 11 | saudarkrokur
# Processing Record 48 of Set 11 | amga
# Processing Record 49 of Set 11 | kaspiyskiy
# Processing Record 0 of Set 12 | labytnangi
# Processing Record 1 of Set 12 | antalaha
# Processing Record 2 of Set 12 | klyuchi
# Processing Record 3 of Set 12 | itaituba
# Processing Record 4 of Set 12 | flores da cunha
# Processing Record 5 of Set 12 | scarborough
# Processing Record 6 of Set 12 | la jolla
# Processing Record 7 of Set 12 | nizhnyaya tavda
# Processing Record 8 of Set 12 | quila
# Processing Record 9 of Set 12 | ilhabela
# Processing Record 10 of Set 12 | zwedru
# Processing Record 11 of Set 12 | nukunonu
# City not found. Skipping...
# Processing Record 12 of Set 12 | chui
# Processing Record 13 of Set 12 | jiwani
# Processing Record 14 of Set 12 | nizhnyaya tura
# Processing Record 15 of Set 12 | okha
# Processing Record 16 of Set 12 | pionerskiy
# Processing Record 17 of Set 12 | shimoda
# Processing Record 18 of Set 12 | nacala
# Processing Record 19 of Set 12 | brezina
# Processing Record 20 of Set 12 | lincoln
# Processing Record 21 of Set 12 | bubaque
# Processing Record 22 of Set 12 | nouadhibou
# Processing Record 23 of Set 12 | kaura namoda
# Processing Record 24 of Set 12 | crucecita
# Processing Record 25 of Set 12 | villamontes
# Processing Record 26 of Set 12 | nosy varika
# Processing Record 27 of Set 12 | cabedelo
# Processing Record 28 of Set 12 | oostrozebeke
# Processing Record 29 of Set 12 | forster
# Processing Record 30 of Set 12 | nadi
# Processing Record 31 of Set 12 | yinchuan
# Processing Record 32 of Set 12 | taulaga
# Processing Record 33 of Set 12 | rukban
# City not found. Skipping...
# Processing Record 34 of Set 12 | svit
# Processing Record 35 of Set 12 | serra talhada
# Processing Record 36 of Set 12 | perelyub
# Processing Record 37 of Set 12 | rice lake
# Processing Record 38 of Set 12 | lukolela
# Processing Record 39 of Set 12 | piton saint-leu
# Processing Record 40 of Set 12 | nanakuli
# Processing Record 41 of Set 12 | greenland
# Processing Record 42 of Set 12 | mao
# Processing Record 43 of Set 12 | kailua-kona
# Processing Record 44 of Set 12 | san
# Processing Record 45 of Set 12 | castillos
# Processing Record 46 of Set 12 | bel ombre
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Activities 6.2.5, 6.2.6

# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          567
# Lat           567
# Lng           567
# Max Temp      567
# Humidity      567
# Cloudiness    567
# Wind Speed    567
# Country       567
# Date          567
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   blackmans bay -43.0167  147.3167      7.08        83          64
# 1           shush  32.1942   48.2436     35.23        13           0
# 2          dunkwa   5.9656   -1.7800     21.09        91          41
# 3  chernomorskoye  45.5039   32.6997     16.91        90          66
# 4          viedma -40.8135  -62.9967      6.73        55           2
#
#    Wind Speed Country        Date
# 0        2.69      AU  1686612107
# 1        4.14      IR  1686612107
# 2        0.96      GH  1686612108
# 3        2.99      UA  1686612071
# 4        3.25      AR  1686612108

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         blackmans bay -43.0167  147.3167      7.08        83          64
# 1                 shush  32.1942   48.2436     35.23        13           0
# 2                dunkwa   5.9656   -1.7800     21.09        91          41
# 3        chernomorskoye  45.5039   32.6997     16.91        90          66
# 4                viedma -40.8135  -62.9967      6.73        55           2
#
#          Wind Speed Country        Date
# City_ID
# 0              2.69      AU  1686612107
# 1              4.14      IR  1686612107
# 2              0.96      GH  1686612108
# 3              2.99      UA  1686612071
# 4              3.25      AR  1686612108

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]
plt.scatter(x_values, y_values)

# Incorporate the other graph properties
plt.title("City Max Temperature vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
y_values = city_data_df["Humidity"]
plt.scatter(x_values, y_values)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
y_values = city_data_df["Cloudiness"]
plt.scatter(x_values, y_values)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
y_values = city_data_df["Wind Speed"]
plt.scatter(x_values, y_values)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Activities 5.3.8, 5.3.9

# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = pd.DataFrame(city_data_df.loc[city_data_df["Lat"] >= 0])

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                 shush  32.1942   48.2436     35.23        13           0
# 2                dunkwa   5.9656   -1.7800     21.09        91          41
# 3        chernomorskoye  45.5039   32.6997     16.91        90          66
# 5                aoulef  26.9667    1.0833     35.18         9           0
# 7            georgetown   5.4112  100.3354     28.96        81          20
#
#          Wind Speed Country        Date
# City_ID
# 1              4.14      IR  1686612107
# 2              0.96      GH  1686612108
# 3              2.99      UA  1686612071
# 5              4.00      DZ  1686612108
# 7              3.09      MY  1686611829

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = pd.DataFrame(city_data_df.loc[city_data_df["Lat"] <= 0])

# Display sample data
southern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          blackmans bay -43.0167  147.3167      7.08        83          64
# 4                 viedma -40.8135  -62.9967      6.73        55           2
# 6              hithadhoo  -0.6000   73.0833     28.00        75          90
# 8        charters towers -20.1000  146.2667     19.65        78          25
# 11        port elizabeth -33.9180   25.5701     14.16        71           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.69      AU  1686612107
# 4              3.25      AR  1686612108
# 6              2.22      MV  1686612108
# 8              0.86      AU  1686612108
# 11             6.69      ZA  1686612109

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.7457626178776939

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,-0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.8372157160772817

# %% [markdown]
# **Discussion about the linear relationship:**
# The correlation of latitude and temperature is negative in the Northern Hemisphere and positive in the Southern Hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.09607242540647343

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.12863497151746037

# %% [markdown]
# **Discussion about the linear relationship:**
# The correlation of humidity and latitude is slightly negative in the Northern Hemisphere and slightly positive in the Southern Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.059976476634832646

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.0659454088128233

# %% [markdown]
# **Discussion about the linear relationship:**
# The correlation of humidity and latitude is slightly negative in the Northern Hemisphere and slightly positive in the Southern Hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.06456408360658987

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.1597578763621744

# %% [markdown]
# **Discussion about the linear relationship:**
# The correlation between latitude and wind speed is slightly negative in the Northern and Southern Hemispheres. The correlation is stronger in the Southern Hemisphere.
