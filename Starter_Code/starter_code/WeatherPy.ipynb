# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 569

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric" 
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url)
        city_json = city_weather.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_json["coord"]["lat"]
        city_lon = city_json["coord"]["lon"]
        city_max_temp = city_json["main"]["temp_max"]
        city_humidity = city_json["main"]["humidity"]
        city_clouds = city_json["clouds"]["all"]
        city_wind = city_json["wind"]["speed"]
        city_country = city_json["sys"]["country"]
        city_date = city_json["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lon, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | la romana
# Processing Record 2 of Set 1 | west island
# Processing Record 3 of Set 1 | dudinka
# Processing Record 4 of Set 1 | antonio enes
# Processing Record 5 of Set 1 | port mathurin
# Processing Record 6 of Set 1 | praia da vitoria
# Processing Record 7 of Set 1 | st. john's
# Processing Record 8 of Set 1 | mount isa
# Processing Record 9 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 10 of Set 1 | bukama
# Processing Record 11 of Set 1 | ponta grossa
# Processing Record 12 of Set 1 | stanley
# Processing Record 13 of Set 1 | nguekhokh
# Processing Record 14 of Set 1 | natal
# Processing Record 15 of Set 1 | ust'-ilimsk
# Processing Record 16 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 17 of Set 1 | adamstown
# Processing Record 18 of Set 1 | luganville
# Processing Record 19 of Set 1 | port-aux-francais
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | namtsy
# Processing Record 22 of Set 1 | blackmans bay
# Processing Record 23 of Set 1 | papatowai
# Processing Record 24 of Set 1 | utrik
# Processing Record 25 of Set 1 | san carlos del zulia
# Processing Record 26 of Set 1 | lihue
# Processing Record 27 of Set 1 | kalmunai
# Processing Record 28 of Set 1 | loango
# Processing Record 29 of Set 1 | broome
# Processing Record 30 of Set 1 | crane
# Processing Record 31 of Set 1 | tralee
# Processing Record 32 of Set 1 | waitangi
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | escarcega
# Processing Record 36 of Set 1 | hawaiian paradise park
# Processing Record 37 of Set 1 | chipinge
# Processing Record 38 of Set 1 | kimbe
# Processing Record 39 of Set 1 | taltal
# Processing Record 40 of Set 1 | nagqu
# Processing Record 41 of Set 1 | aykhal
# Processing Record 42 of Set 1 | grytviken
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | puerto natales
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | papao
# Processing Record 47 of Set 1 | bijar
# Processing Record 48 of Set 1 | lagoa
# Processing Record 49 of Set 1 | remire-montjoly
# Processing Record 50 of Set 1 | vila velha
# Processing Record 0 of Set 2 | daru
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | invercargill
# Processing Record 3 of Set 2 | khanty-mansiysk
# Processing Record 4 of Set 2 | tiksi
# Processing Record 5 of Set 2 | isafjordur
# Processing Record 6 of Set 2 | codrington
# Processing Record 7 of Set 2 | qaqortoq
# Processing Record 8 of Set 2 | edinburgh of the seven seas
# Processing Record 9 of Set 2 | mahenge
# Processing Record 10 of Set 2 | hammerfest
# Processing Record 11 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 12 of Set 2 | dwarka
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | longboat key
# Processing Record 15 of Set 2 | gromitz
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | alice springs
# Processing Record 18 of Set 2 | tura
# Processing Record 19 of Set 2 | djambala
# Processing Record 20 of Set 2 | mujiayingzi
# Processing Record 21 of Set 2 | zouerate
# Processing Record 22 of Set 2 | pisco
# Processing Record 23 of Set 2 | chinde
# Processing Record 24 of Set 2 | terebovlya
# Processing Record 25 of Set 2 | pyt-yakh
# Processing Record 26 of Set 2 | baise city
# Processing Record 27 of Set 2 | cockburn town
# Processing Record 28 of Set 2 | ilha de mocambique
# Processing Record 29 of Set 2 | olonkinbyen
# Processing Record 30 of Set 2 | villa gesell
# Processing Record 31 of Set 2 | garachico
# Processing Record 32 of Set 2 | yuzhno-kurilsk
# Processing Record 33 of Set 2 | fort bragg
# Processing Record 34 of Set 2 | pervomayskiy
# Processing Record 35 of Set 2 | tazovsky
# Processing Record 36 of Set 2 | borogontsy
# Processing Record 37 of Set 2 | rio grande
# Processing Record 38 of Set 2 | bilibino
# Processing Record 39 of Set 2 | nova vicosa
# Processing Record 40 of Set 2 | labrador city
# Processing Record 41 of Set 2 | constitucion
# Processing Record 42 of Set 2 | chingirlau
# Processing Record 43 of Set 2 | bredasdorp
# Processing Record 44 of Set 2 | kingston
# Processing Record 45 of Set 2 | cambridge
# Processing Record 46 of Set 2 | byram
# Processing Record 47 of Set 2 | vorgashor
# Processing Record 48 of Set 2 | vodnyy
# Processing Record 49 of Set 2 | longyearbyen
# Processing Record 0 of Set 3 | puerto baquerizo moreno
# Processing Record 1 of Set 3 | kapa'a
# Processing Record 2 of Set 3 | padang
# Processing Record 3 of Set 3 | ardestan
# Processing Record 4 of Set 3 | borzya
# Processing Record 5 of Set 3 | fale old settlement
# Processing Record 6 of Set 3 | lorengau
# Processing Record 7 of Set 3 | puma
# Processing Record 8 of Set 3 | beloyarskiy
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | carnikava
# Processing Record 11 of Set 3 | talnakh
# Processing Record 12 of Set 3 | hithadhoo
# Processing Record 13 of Set 3 | jiuquan
# Processing Record 14 of Set 3 | saint-pierre
# Processing Record 15 of Set 3 | whitehorse
# Processing Record 16 of Set 3 | ilulissat
# Processing Record 17 of Set 3 | port lincoln
# Processing Record 18 of Set 3 | ust-nera
# Processing Record 19 of Set 3 | aginskoye
# Processing Record 20 of Set 3 | hamilton
# Processing Record 21 of Set 3 | manokwari
# Processing Record 22 of Set 3 | vadso
# Processing Record 23 of Set 3 | fort st. john
# Processing Record 24 of Set 3 | xifeng
# Processing Record 25 of Set 3 | bardai
# Processing Record 26 of Set 3 | sao felix do xingu
# Processing Record 27 of Set 3 | fort-shevchenko
# Processing Record 28 of Set 3 | kalevala
# Processing Record 29 of Set 3 | badger
# Processing Record 30 of Set 3 | udangudi
# Processing Record 31 of Set 3 | sitia
# Processing Record 32 of Set 3 | kununurra
# Processing Record 33 of Set 3 | dunedin
# Processing Record 34 of Set 3 | nemuro
# Processing Record 35 of Set 3 | rosso
# Processing Record 36 of Set 3 | yacuiba
# Processing Record 37 of Set 3 | wenatchee
# Processing Record 38 of Set 3 | aasiaat
# Processing Record 39 of Set 3 | okha
# Processing Record 40 of Set 3 | college
# Processing Record 41 of Set 3 | tolanaro
# Processing Record 42 of Set 3 | taoudenni
# Processing Record 43 of Set 3 | polyarnyy
# Processing Record 44 of Set 3 | tazacorte
# Processing Record 45 of Set 3 | taibet
# City not found. Skipping...
# Processing Record 46 of Set 3 | dakhla
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | cabo san lucas
# Processing Record 49 of Set 3 | tofol
# Processing Record 0 of Set 4 | kapenguria
# Processing Record 1 of Set 4 | shankill
# Processing Record 2 of Set 4 | ghat
# Processing Record 3 of Set 4 | mount pearl
# Processing Record 4 of Set 4 | campobello di mazara
# Processing Record 5 of Set 4 | newman
# Processing Record 6 of Set 4 | alenquer
# Processing Record 7 of Set 4 | arboletes
# Processing Record 8 of Set 4 | lesina
# Processing Record 9 of Set 4 | alofi
# Processing Record 10 of Set 4 | champerico
# Processing Record 11 of Set 4 | pagar alam
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | la passe
# Processing Record 14 of Set 4 | geraldton
# Processing Record 15 of Set 4 | arkhangel'sk
# Processing Record 16 of Set 4 | kruisfontein
# Processing Record 17 of Set 4 | igarka
# Processing Record 18 of Set 4 | al hudaydah
# Processing Record 19 of Set 4 | zakamensk
# Processing Record 20 of Set 4 | malanje
# Processing Record 21 of Set 4 | lichinga
# Processing Record 22 of Set 4 | youkounkoun
# Processing Record 23 of Set 4 | nova sintra
# Processing Record 24 of Set 4 | szolnok
# Processing Record 25 of Set 4 | mega
# Processing Record 26 of Set 4 | inirida
# Processing Record 27 of Set 4 | freeport
# Processing Record 28 of Set 4 | brookings
# Processing Record 29 of Set 4 | enewetak
# Processing Record 30 of Set 4 | udachny
# Processing Record 31 of Set 4 | bikenibeu village
# Processing Record 32 of Set 4 | naracoorte
# Processing Record 33 of Set 4 | sendafa
# Processing Record 34 of Set 4 | nizhnesortymskiy
# Processing Record 35 of Set 4 | taitung city
# Processing Record 36 of Set 4 | pangody
# Processing Record 37 of Set 4 | haimen
# Processing Record 38 of Set 4 | essaouira
# Processing Record 39 of Set 4 | sake
# Processing Record 40 of Set 4 | mariehamn
# Processing Record 41 of Set 4 | taupo
# Processing Record 42 of Set 4 | kerikeri
# Processing Record 43 of Set 4 | minab
# Processing Record 44 of Set 4 | georgetown
# Processing Record 45 of Set 4 | muisne
# Processing Record 46 of Set 4 | argo
# Processing Record 47 of Set 4 | maues
# Processing Record 48 of Set 4 | walvis bay
# Processing Record 49 of Set 4 | sarmiento
# Processing Record 0 of Set 5 | taro
# Processing Record 1 of Set 5 | serdar
# Processing Record 2 of Set 5 | ostersund
# Processing Record 3 of Set 5 | afaahiti
# Processing Record 4 of Set 5 | whyalla stuart
# City not found. Skipping...
# Processing Record 5 of Set 5 | kashmor
# Processing Record 6 of Set 5 | klyuchi
# Processing Record 7 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 8 of Set 5 | bandarbeyla
# Processing Record 9 of Set 5 | saipan
# Processing Record 10 of Set 5 | anadyr
# Processing Record 11 of Set 5 | labasa
# Processing Record 12 of Set 5 | bojia
# Processing Record 13 of Set 5 | kribi
# Processing Record 14 of Set 5 | uturoa
# Processing Record 15 of Set 5 | lincoln city
# Processing Record 16 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 17 of Set 5 | ilanskiy
# Processing Record 18 of Set 5 | jaguey grande
# Processing Record 19 of Set 5 | san pedro
# Processing Record 20 of Set 5 | acapulco de juarez
# Processing Record 21 of Set 5 | vila franca do campo
# Processing Record 22 of Set 5 | las lomitas
# Processing Record 23 of Set 5 | margate
# Processing Record 24 of Set 5 | porto velho
# Processing Record 25 of Set 5 | adrar
# Processing Record 26 of Set 5 | inari
# Processing Record 27 of Set 5 | sao vicente
# Processing Record 28 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 29 of Set 5 | tayshet
# Processing Record 30 of Set 5 | boyolangu
# Processing Record 31 of Set 5 | suai
# City not found. Skipping...
# Processing Record 32 of Set 5 | hilo
# Processing Record 33 of Set 5 | mejit
# Processing Record 34 of Set 5 | thompson
# Processing Record 35 of Set 5 | waiuku
# Processing Record 36 of Set 5 | djougou
# Processing Record 37 of Set 5 | ad-damazin
# Processing Record 38 of Set 5 | marquette
# Processing Record 39 of Set 5 | rongelap
# Processing Record 40 of Set 5 | chonchi
# Processing Record 41 of Set 5 | tommot
# Processing Record 42 of Set 5 | ta`u
# Processing Record 43 of Set 5 | san antonio de pale
# Processing Record 44 of Set 5 | orange
# Processing Record 45 of Set 5 | boende
# Processing Record 46 of Set 5 | margaret river
# Processing Record 47 of Set 5 | lata
# Processing Record 48 of Set 5 | mount gambier
# Processing Record 49 of Set 5 | kavieng
# Processing Record 0 of Set 6 | quellon
# Processing Record 1 of Set 6 | wenling
# Processing Record 2 of Set 6 | buka
# Processing Record 3 of Set 6 | frinton-on-sea
# Processing Record 4 of Set 6 | houlton
# Processing Record 5 of Set 6 | katabu
# Processing Record 6 of Set 6 | la sarre
# Processing Record 7 of Set 6 | marsh harbour
# Processing Record 8 of Set 6 | susuman
# Processing Record 9 of Set 6 | vorkuta
# Processing Record 10 of Set 6 | floro
# Processing Record 11 of Set 6 | jamestown
# Processing Record 12 of Set 6 | mitu
# Processing Record 13 of Set 6 | kamina
# Processing Record 14 of Set 6 | hermanus
# Processing Record 15 of Set 6 | weno
# Processing Record 16 of Set 6 | lahij
# Processing Record 17 of Set 6 | quibdo
# Processing Record 18 of Set 6 | kariba
# Processing Record 19 of Set 6 | hami
# Processing Record 20 of Set 6 | belyy yar
# Processing Record 21 of Set 6 | yarmouth
# Processing Record 22 of Set 6 | carnarvon
# Processing Record 23 of Set 6 | port isabel
# Processing Record 24 of Set 6 | bumba
# Processing Record 25 of Set 6 | ancud
# Processing Record 26 of Set 6 | gandajika
# Processing Record 27 of Set 6 | san angelo
# Processing Record 28 of Set 6 | mili
# Processing Record 29 of Set 6 | sitka
# Processing Record 30 of Set 6 | kingscliff
# Processing Record 31 of Set 6 | qamdo
# Processing Record 32 of Set 6 | belabo
# Processing Record 33 of Set 6 | canutama
# Processing Record 34 of Set 6 | banda aceh
# Processing Record 35 of Set 6 | dul'durga
# Processing Record 36 of Set 6 | saint-valery-en-caux
# Processing Record 37 of Set 6 | puerto santa
# Processing Record 38 of Set 6 | williams lake
# Processing Record 39 of Set 6 | kodiak
# Processing Record 40 of Set 6 | laikit, laikit ii (dimembe)
# Processing Record 41 of Set 6 | gracemere
# Processing Record 42 of Set 6 | port blair
# Processing Record 43 of Set 6 | guider
# Processing Record 44 of Set 6 | centerville
# Processing Record 45 of Set 6 | atafu village
# Processing Record 46 of Set 6 | poso
# Processing Record 47 of Set 6 | tsiombe
# Processing Record 48 of Set 6 | naliya
# Processing Record 49 of Set 6 | avesta
# Processing Record 0 of Set 7 | biassono
# Processing Record 1 of Set 7 | winejok
# City not found. Skipping...
# Processing Record 2 of Set 7 | fuxin
# Processing Record 3 of Set 7 | sisimiut
# Processing Record 4 of Set 7 | sampacho
# Processing Record 5 of Set 7 | okahandja
# Processing Record 6 of Set 7 | sao gabriel da cachoeira
# Processing Record 7 of Set 7 | camalu
# Processing Record 8 of Set 7 | san patricio
# Processing Record 9 of Set 7 | el alto
# Processing Record 10 of Set 7 | mbaiki
# Processing Record 11 of Set 7 | wailua homesteads
# Processing Record 12 of Set 7 | ilebo
# Processing Record 13 of Set 7 | san ignacio de velasco
# Processing Record 14 of Set 7 | subaykhan
# Processing Record 15 of Set 7 | yekaterinoslavka
# Processing Record 16 of Set 7 | wajir
# Processing Record 17 of Set 7 | zhangzhou
# Processing Record 18 of Set 7 | namibe
# Processing Record 19 of Set 7 | puerto deseado
# Processing Record 20 of Set 7 | qorovulbozor
# Processing Record 21 of Set 7 | revda
# Processing Record 22 of Set 7 | tvoroyri
# Processing Record 23 of Set 7 | panjab
# Processing Record 24 of Set 7 | muzayri'
# City not found. Skipping...
# Processing Record 25 of Set 7 | barmer
# Processing Record 26 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 27 of Set 7 | lompoc
# Processing Record 28 of Set 7 | stephenville
# Processing Record 29 of Set 7 | upata
# Processing Record 30 of Set 7 | turabah
# Processing Record 31 of Set 7 | nebbi
# Processing Record 32 of Set 7 | dire
# Processing Record 33 of Set 7 | portland
# Processing Record 34 of Set 7 | chibougamau
# Processing Record 35 of Set 7 | greenville
# Processing Record 36 of Set 7 | sotik post
# Processing Record 37 of Set 7 | bengkulu
# Processing Record 38 of Set 7 | mae ramat
# Processing Record 39 of Set 7 | altai
# Processing Record 40 of Set 7 | xining
# Processing Record 41 of Set 7 | soe
# Processing Record 42 of Set 7 | port glaud
# City not found. Skipping...
# Processing Record 43 of Set 7 | puerto armuelles
# Processing Record 44 of Set 7 | flying fish cove
# Processing Record 45 of Set 7 | lysekil
# Processing Record 46 of Set 7 | kolarovo
# Processing Record 47 of Set 7 | illizi
# Processing Record 48 of Set 7 | kavaratti
# Processing Record 49 of Set 7 | fallsburg
# Processing Record 0 of Set 8 | nar'yan-mar
# Processing Record 1 of Set 8 | silver city
# Processing Record 2 of Set 8 | shilin
# Processing Record 3 of Set 8 | berdigestyakh
# Processing Record 4 of Set 8 | mbale
# Processing Record 5 of Set 8 | guigang
# Processing Record 6 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 7 of Set 8 | el maamoura
# Processing Record 8 of Set 8 | nuuk
# Processing Record 9 of Set 8 | lauro de freitas
# Processing Record 10 of Set 8 | soja
# Processing Record 11 of Set 8 | balqash
# Processing Record 12 of Set 8 | maumere
# Processing Record 13 of Set 8 | huron
# Processing Record 14 of Set 8 | tibanbang
# Processing Record 15 of Set 8 | sansanne-mango
# Processing Record 16 of Set 8 | roxas
# Processing Record 17 of Set 8 | inarajan village
# Processing Record 18 of Set 8 | betio village
# Processing Record 19 of Set 8 | constantia
# Processing Record 20 of Set 8 | hadibu
# Processing Record 21 of Set 8 | sabzevar
# Processing Record 22 of Set 8 | labuan
# Processing Record 23 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 24 of Set 8 | cable beach
# City not found. Skipping...
# Processing Record 25 of Set 8 | mertola
# Processing Record 26 of Set 8 | wynyard
# Processing Record 27 of Set 8 | amga
# Processing Record 28 of Set 8 | formosa do rio preto
# Processing Record 29 of Set 8 | haldensleben i
# Processing Record 30 of Set 8 | buenaventura
# Processing Record 31 of Set 8 | saldanha
# Processing Record 32 of Set 8 | ola
# Processing Record 33 of Set 8 | somerset
# Processing Record 34 of Set 8 | naestved
# Processing Record 35 of Set 8 | iskateley
# Processing Record 36 of Set 8 | khost
# Processing Record 37 of Set 8 | kenora
# Processing Record 38 of Set 8 | puerto aysen
# Processing Record 39 of Set 8 | matinha
# Processing Record 40 of Set 8 | beledweyne
# Processing Record 41 of Set 8 | sabang
# Processing Record 42 of Set 8 | powell river
# Processing Record 43 of Set 8 | chiang rai
# Processing Record 44 of Set 8 | tefe
# Processing Record 45 of Set 8 | kudahuvadhoo
# Processing Record 46 of Set 8 | winterville
# Processing Record 47 of Set 8 | lebu
# Processing Record 48 of Set 8 | sarikei
# Processing Record 49 of Set 8 | santo antonio do sudoeste
# Processing Record 0 of Set 9 | magadan
# Processing Record 1 of Set 9 | aden
# Processing Record 2 of Set 9 | santa cruz
# Processing Record 3 of Set 9 | preobrazheniye
# Processing Record 4 of Set 9 | usogorsk
# Processing Record 5 of Set 9 | abadiania
# Processing Record 6 of Set 9 | kerema
# Processing Record 7 of Set 9 | wundanyi
# Processing Record 8 of Set 9 | varva
# Processing Record 9 of Set 9 | bethanie
# Processing Record 10 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 11 of Set 9 | agat village
# Processing Record 12 of Set 9 | luang namtha
# Processing Record 13 of Set 9 | sabaneta
# Processing Record 14 of Set 9 | yazman
# Processing Record 15 of Set 9 | saudarkrokur
# Processing Record 16 of Set 9 | misratah
# Processing Record 17 of Set 9 | ferkessedougou
# Processing Record 18 of Set 9 | mhamid
# Processing Record 19 of Set 9 | abu zabad
# Processing Record 20 of Set 9 | bhavnagar
# Processing Record 21 of Set 9 | gunnedah
# Processing Record 22 of Set 9 | santa rosalia
# Processing Record 23 of Set 9 | keflavik
# Processing Record 24 of Set 9 | northam
# Processing Record 25 of Set 9 | morehead city
# Processing Record 26 of Set 9 | laela
# Processing Record 27 of Set 9 | inhambane
# Processing Record 28 of Set 9 | mumford
# Processing Record 29 of Set 9 | orsa
# Processing Record 30 of Set 9 | bereznik
# Processing Record 31 of Set 9 | isola di capo rizzuto
# Processing Record 32 of Set 9 | lesosibirsk
# Processing Record 33 of Set 9 | kirakira
# Processing Record 34 of Set 9 | ikem
# Processing Record 35 of Set 9 | la malbaie
# Processing Record 36 of Set 9 | opuwo
# Processing Record 37 of Set 9 | ust'-kulom
# Processing Record 38 of Set 9 | greymouth
# Processing Record 39 of Set 9 | fonadhoo
# City not found. Skipping...
# Processing Record 40 of Set 9 | sechura
# Processing Record 41 of Set 9 | forster
# Processing Record 42 of Set 9 | mil'kovo
# Processing Record 43 of Set 9 | neftcala
# Processing Record 44 of Set 9 | suva
# Processing Record 45 of Set 9 | general mosconi
# Processing Record 46 of Set 9 | sinabang
# Processing Record 47 of Set 9 | muynoq
# Processing Record 48 of Set 9 | ilhabela
# Processing Record 49 of Set 9 | imamoglu
# Processing Record 0 of Set 10 | minas de marcona
# Processing Record 1 of Set 10 | hoxtolgay
# City not found. Skipping...
# Processing Record 2 of Set 10 | holualoa
# Processing Record 3 of Set 10 | san jose village
# City not found. Skipping...
# Processing Record 4 of Set 10 | tachilek
# City not found. Skipping...
# Processing Record 5 of Set 10 | sultanah
# Processing Record 6 of Set 10 | bac kan
# Processing Record 7 of Set 10 | lesogorsk
# Processing Record 8 of Set 10 | general pico
# Processing Record 9 of Set 10 | sinop
# Processing Record 10 of Set 10 | rio gallegos
# Processing Record 11 of Set 10 | sihanoukville
# Processing Record 12 of Set 10 | mirny
# Processing Record 13 of Set 10 | progreso
# Processing Record 14 of Set 10 | nieuw amsterdam
# Processing Record 15 of Set 10 | rhinelander
# Processing Record 16 of Set 10 | tupiza
# Processing Record 17 of Set 10 | sumberpucung
# Processing Record 18 of Set 10 | khovd
# Processing Record 19 of Set 10 | kirensk
# Processing Record 20 of Set 10 | debre werk'
# Processing Record 21 of Set 10 | ulladulla
# Processing Record 22 of Set 10 | guerrero negro
# Processing Record 23 of Set 10 | eagle mountain
# Processing Record 24 of Set 10 | bereeda
# Processing Record 25 of Set 10 | erenhot
# Processing Record 26 of Set 10 | liwale
# Processing Record 27 of Set 10 | carutapera
# Processing Record 28 of Set 10 | labytnangi
# Processing Record 29 of Set 10 | mangalagiri
# Processing Record 30 of Set 10 | riohacha
# Processing Record 31 of Set 10 | mayqayyng
# Processing Record 32 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 33 of Set 10 | touros
# Processing Record 34 of Set 10 | al bardiyah
# Processing Record 35 of Set 10 | grand falls-windsor
# Processing Record 36 of Set 10 | malpica
# Processing Record 37 of Set 10 | zangguy
# City not found. Skipping...
# Processing Record 38 of Set 10 | fisterra
# Processing Record 39 of Set 10 | cabedelo
# Processing Record 40 of Set 10 | jatai
# Processing Record 41 of Set 10 | pontianak
# Processing Record 42 of Set 10 | paranaiba
# Processing Record 43 of Set 10 | bandar abbas
# Processing Record 44 of Set 10 | lebedyan'
# Processing Record 45 of Set 10 | sonsorol village
# City not found. Skipping...
# Processing Record 46 of Set 10 | antalaha
# Processing Record 47 of Set 10 | sanctuary point
# Processing Record 48 of Set 10 | tirlyanskiy
# Processing Record 49 of Set 10 | kangding
# Processing Record 0 of Set 11 | winnemucca
# Processing Record 1 of Set 11 | teknaf
# Processing Record 2 of Set 11 | gorontalo
# Processing Record 3 of Set 11 | olgii
# City not found. Skipping...
# Processing Record 4 of Set 11 | toliara
# Processing Record 5 of Set 11 | queenstown
# Processing Record 6 of Set 11 | prince rupert
# Processing Record 7 of Set 11 | barra de santo antonio
# Processing Record 8 of Set 11 | vernon
# Processing Record 9 of Set 11 | road town
# Processing Record 10 of Set 11 | fresno
# Processing Record 11 of Set 11 | punta arenas
# Processing Record 12 of Set 11 | saint-francois
# Processing Record 13 of Set 11 | payson
# Processing Record 14 of Set 11 | galle
# Processing Record 15 of Set 11 | vilyuysk
# Processing Record 16 of Set 11 | oodweyne
# Processing Record 17 of Set 11 | colonia
# Processing Record 18 of Set 11 | vilyuchinsk
# Processing Record 19 of Set 11 | wuchuan
# Processing Record 20 of Set 11 | dzilam gonzalez
# Processing Record 21 of Set 11 | george
# Processing Record 22 of Set 11 | los andes
# Processing Record 23 of Set 11 | thinadhoo
# Processing Record 24 of Set 11 | cidreira
# Processing Record 25 of Set 11 | twon-brass
# Processing Record 26 of Set 11 | katsuren-haebaru
# Processing Record 27 of Set 11 | cunha
# Processing Record 28 of Set 11 | harstad
# Processing Record 29 of Set 11 | bamboo flat
# Processing Record 30 of Set 11 | basavana bagevadi
# Processing Record 31 of Set 11 | gaspe
# Processing Record 32 of Set 11 | goito
# Processing Record 33 of Set 11 | macouria
# Processing Record 34 of Set 11 | dubbo
# Processing Record 35 of Set 11 | launceston
# Processing Record 36 of Set 11 | monguno
# Processing Record 37 of Set 11 | fortuna
# Processing Record 38 of Set 11 | uaboe
# City not found. Skipping...
# Processing Record 39 of Set 11 | fortaleza
# Processing Record 40 of Set 11 | rakvere
# Processing Record 41 of Set 11 | cerqueira cesar
# Processing Record 42 of Set 11 | port douglas
# Processing Record 43 of Set 11 | jeremie
# Processing Record 44 of Set 11 | bakanas
# Processing Record 45 of Set 11 | malango
# Processing Record 46 of Set 11 | hasaki
# Processing Record 47 of Set 11 | da nang
# Processing Record 48 of Set 11 | nadym
# Processing Record 49 of Set 11 | kerewan
# Processing Record 0 of Set 12 | santa elena de uairen
# Processing Record 1 of Set 12 | tadine
# Processing Record 2 of Set 12 | padampur
# Processing Record 3 of Set 12 | smolensk
# Processing Record 4 of Set 12 | qaisumah
# Processing Record 5 of Set 12 | east london
# Processing Record 6 of Set 12 | tshikapa
# Processing Record 7 of Set 12 | miches
# Processing Record 8 of Set 12 | paramonga
# Processing Record 9 of Set 12 | tromso
# Processing Record 10 of Set 12 | qalat
# Processing Record 11 of Set 12 | mpongwe
# Processing Record 12 of Set 12 | port-saint-louis-du-rhone
# Processing Record 13 of Set 12 | arraial do cabo
# Processing Record 14 of Set 12 | monteagudo
# Processing Record 15 of Set 12 | zeya
# Processing Record 16 of Set 12 | pingliang
# Processing Record 17 of Set 12 | moyale
# Processing Record 18 of Set 12 | bouarfa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Activities 6.2.5, 6.2.6

# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          544
# Lat           544
# Lng           544
# Max Temp      544
# Humidity      544
# Cloudiness    544
# Wind Speed    544
# Country       544
# Date          544
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0      la romana  18.4273 -68.9728     31.20        79          40
# 1    west island -12.1568  96.8225     25.99        83          75
# 2        dudinka  69.4058  86.1778      6.52        57          96
# 3   antonio enes -16.2325  39.9086     23.38        79           0
# 4  port mathurin -19.6833  63.4167     24.72        72           5
#
#    Wind Speed Country        Date
# 0        4.12      DO  1686264191
# 1        9.26      CC  1686264191
# 2        6.74      RU  1686264192
# 3        2.43      MZ  1686264192
# 4        8.02      MU  1686264192

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            la romana  18.4273 -68.9728     31.20        79          40
# 1          west island -12.1568  96.8225     25.99        83          75
# 2              dudinka  69.4058  86.1778      6.52        57          96
# 3         antonio enes -16.2325  39.9086     23.38        79           0
# 4        port mathurin -19.6833  63.4167     24.72        72           5
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      DO  1686264191
# 1              9.26      CC  1686264191
# 2              6.74      RU  1686264192
# 3              2.43      MZ  1686264192
# 4              8.02      MU  1686264192

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]
plt.scatter(x_values, y_values)

# Incorporate the other graph properties
plt.title("City Max Temperature vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
y_values = city_data_df["Humidity"]
plt.scatter(x_values, y_values)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
y_values = city_data_df["Cloudiness"]
plt.scatter(x_values, y_values)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
y_values = city_data_df["Wind Speed"]
plt.scatter(x_values, y_values)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Activities 5.3.8, 5.3.9

# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = pd.DataFrame(city_data_df.loc[city_data_df["Lat"] >= 0])

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               la romana  18.4273 -68.9728     31.20        79          40
# 2                 dudinka  69.4058  86.1778      6.52        57          96
# 5        praia da vitoria  38.7333 -27.0667     19.14        82          40
# 6              st. john's  47.5649 -52.7093     13.66        94          75
# 10                stanley  54.8680  -1.6985     10.39        78          75
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      DO  1686264191
# 2              6.74      RU  1686264192
# 5              4.68      PT  1686264192
# 6              4.12      CA  1686264022
# 10             3.09      GB  1686264193

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = pd.DataFrame(city_data_df.loc[city_data_df["Lat"] <= 0])

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          west island -12.1568   96.8225     25.99        83          75
# 3         antonio enes -16.2325   39.9086     23.38        79           0
# 4        port mathurin -19.6833   63.4167     24.72        72           5
# 7            mount isa -20.7333  139.5000     15.87        51          42
# 8               bukama  -9.2000   25.8500     21.82        52          35
#
#          Wind Speed Country        Date
# City_ID
# 1              9.26      CC  1686264191
# 3              2.43      MZ  1686264192
# 4              8.02      MU  1686264192
# 7              6.17      AU  1686264192
# 8              0.84      CD  1686264192

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.7309738905622467

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,-0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.8035752377954278

# %% [markdown]
# **Discussion about the linear relationship:**
# The correlation of latitude and temperature is negative in the Northern Hemisphere and positive in the Southern Hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.11558463415414855

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.12916363349411586

# %% [markdown]
# **Discussion about the linear relationship:**
# The correlation of humidity and latitude is slightly negative in the Northern Hemisphere and slightly positive in the Southern Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.06865818523070766

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.10788279018429171

# %% [markdown]
# **Discussion about the linear relationship:**
# The correlation of humidity and latitude is slightly negative in the Northern Hemisphere and slightly positive in the Southern Hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.07103148458811857

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.30707405756042583

# %% [markdown]
# **Discussion about the linear relationship:**
# The correlation between latitude and wind speed is slightly negative in the Northern and Southern Hemispheres. The correlation is stronger in the Southern Hemisphere.
